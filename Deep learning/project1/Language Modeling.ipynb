# %% [markdown]
# ## **RNN (Recurrent Neural Network) - Language Mode**

# %% [markdown]
# `Language Modeling (LM) is one of the foundational task in the realm of natural language processing (NLP). At a high level, the goal is to predict the n + 1 token in a sequence given the n tokens preceding it. A well trained language model are used in applications such as machine translation.`

# %% [markdown]
# ### **DataPreparation**

# %%
import string
import re
# define function to load and read text file 
# load file
def loading_file(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %%
# We will be splitting the text into words/tokens based on spaces, and from the first few words, 
# we can see that some words are separated by "--",
# hence we'll replace that with a space.
# Removing punctuation marks and retain only alphabetical words.
def clean_txt(txt):
    # replace '--' with a space ' '
    doc = txt.replace('--', ' ')
    # split into tokens by white space
    tokens = txt.split()
    # prepare regex for char filtering
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # remove punctuation from each word
    tokens = [re_punc.sub('', w) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # make lower case
    tokens = [word.lower() for word in tokens]
    return tokens

# %%
# save tokens to file, one dialog per line
def save_txt(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# %%
# load document
in_filename = '/content/republic_clean.txt'
doc= loading_file(in_filename)
print(doc[:200])
# Out:
# BOOK I.
#
# I went down yesterday to the Piraeus with Glaucon the son of Ariston,
# that I might offer up my prayers to the goddess (Bendis, the Thracian
# Artemis.); and also because I wanted to see in what

# %%
# clean document
tokens = clean_txt(doc)
print(tokens[:100])
print('Total Tokens: %d' % len(tokens))
print('Unique Tokens: %d' % len(set(tokens)))
# organize into sequences of tokens
length = 50 +1
sequences = list()
# Out:
# ['book', 'i', 'i', 'went', 'down', 'yesterday', 'to', 'the', 'piraeus', 'with', 'glaucon', 'the', 'son', 'of', 'ariston', 'that', 'i', 'might', 'offer', 'up', 'my', 'prayers', 'to', 'the', 'goddess', 'bendis', 'the', 'thracian', 'artemis', 'and', 'also', 'because', 'i', 'wanted', 'to', 'see', 'in', 'what', 'manner', 'they', 'would', 'celebrate', 'the', 'festival', 'which', 'was', 'a', 'new', 'thing', 'i', 'was', 'delighted', 'with', 'the', 'procession', 'of', 'the', 'inhabitants', 'but', 'that', 'of', 'the', 'thracians', 'was', 'equally', 'if', 'not', 'more', 'beautiful', 'when', 'we', 'had', 'finished', 'our', 'prayers', 'and', 'viewed', 'the', 'spectacle', 'we', 'turned', 'in', 'the', 'direction', 'of', 'the', 'city', 'and', 'at', 'that', 'instant', 'polemarchus', 'the', 'son', 'of', 'cephalus', 'chanced', 'to', 'catch', 'sight']
# Total Tokens: 118214
# Unique Tokens: 7837

# %%
for i in range(length, len(tokens)):
    # select sequence of tokens
    seq = tokens[i-length:i]
    # convert into a line
    line = ' '.join(seq)
    # store
    sequences.append(line)
print('Total Sequences: %d' % len(sequences))
# save sequences to file
out_filename = '/content/republic_clean_seq.txt'
save_txt(sequences, out_filename)
# Out:
# Total Sequences: 118163

# %% [markdown]
# ---

# %% [markdown]
# ## **Build Model LSTM**

# %%
from numpy import array
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM ,GRU,Bidirectional
from keras.layers import Embedding
from pickle import dump, load

# %%
# define the model
def define_model(vocab_size, seq_length):
    model = Sequential()
    model.add(Embedding(vocab_size, 50, input_length=seq_length))
    model.add(LSTM(128, return_sequences=True))
    model.add(Bidirectional(GRU(64)))
    model.add(Dense(300, activation='relu'))
    model.add(Dense(vocab_size, activation='softmax'))
    # compile network
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # summarize defined model
    model.summary()
    plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %%
# load
in_filename = '/content/republic_clean_seq.txt'
doc = loading_file(in_filename)
lines = doc.split('\n')
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)
# vocabulary size
vocab_size = len(tokenizer.word_index) + 1
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)
seq_length = X.shape[1]

# %%
# define model
model = define_model(vocab_size, seq_length)
# fit model
model.fit(X, y, batch_size=300, epochs=150)
# save the model to file
model.save('model.h5')
# save the tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 50)            391900
#
#  lstm (LSTM)                 (None, 50, 128)           91648
#
#  bidirectional (Bidirectiona  (None, 128)              74496
#  l)
#
#  dense (Dense)               (None, 300)               38700
#
#  dense_1 (Dense)             (None, 7838)              2359238
#
# =================================================================
# Total params: 2,955,982
# Trainable params: 2,955,982
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 394/394 [==============================] - 14s 23ms/step - loss: 6.3600 - accuracy: 0.0585
# Epoch 2/150
# 394/394 [==============================] - 9s 23ms/step - loss: 5.9057 - accuracy: 0.0867
# Epoch 3/150
# 394/394 [==============================] - 9s 23ms/step - loss: 5.5900 - accuracy: 0.1166
# Epoch 4/150
# 394/394 [==============================] - 9s 23ms/step - loss: 5.3374 - accuracy: 0.1393
# Epoch 5/150
# 394/394 [==============================] - 9s 23ms/step - loss: 5.1564 - accuracy: 0.1515
# Epoch 6/150
# 394/394 [==============================] - 10s 25ms/step - loss: 5.0193 - accuracy: 0.1588
# Epoch 7/150
# 394/394 [==============================] - 9s 23ms/step - loss: 4.9033 - accuracy: 0.1632
# Epoch 8/150
# 394/394 [==============================] - 9s 23ms/step - loss: 4.7934 - accuracy: 0.1687
# Epoch 9/150
# 394/394 [==============================] - 9s 23ms/step - loss: 4.6840 - accuracy: 0.1719
# Epoch 10/150
# 394/394 [==============================] - 9s 23ms/step - loss: 4.5763 - accuracy: 0.1756
# Epoch 11/150
# 394/394 [==============================] - 9s 23ms/step - loss: 4.4647 - accuracy: 0.1787
# Epoch 12/150
# 394/394 [==============================] - 9s 23ms/step - loss: 4.3531 - accuracy: 0.1824
# Epoch 13/150
# 394/394 [==============================] - 9s 23ms/step - loss: 4.2328 - accuracy: 0.1864
# Epoch 14/150
# 394/394 [==============================] - 9s 23ms/step - loss: 4.1106 - accuracy: 0.1930
# Epoch 15/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.9839 - accuracy: 0.2017
# Epoch 16/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.8563 - accuracy: 0.2149
# Epoch 17/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.7317 - accuracy: 0.2294
# Epoch 18/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.6091 - accuracy: 0.2447
# Epoch 19/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.4913 - accuracy: 0.2612
# Epoch 20/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.3797 - accuracy: 0.2779
# Epoch 21/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.2783 - accuracy: 0.2918
# Epoch 22/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.1885 - accuracy: 0.3033
# Epoch 23/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.0987 - accuracy: 0.3190
# Epoch 24/150
# 394/394 [==============================] - 9s 23ms/step - loss: 3.0186 - accuracy: 0.3308
# Epoch 25/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.9442 - accuracy: 0.3422
# Epoch 26/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.8737 - accuracy: 0.3528
# Epoch 27/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.8062 - accuracy: 0.3636
# Epoch 28/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.7433 - accuracy: 0.3734
# Epoch 29/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.6822 - accuracy: 0.3854
# Epoch 30/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.6267 - accuracy: 0.3940
# Epoch 31/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.5692 - accuracy: 0.4042
# Epoch 32/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.5139 - accuracy: 0.4150
# Epoch 33/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.4631 - accuracy: 0.4227
# Epoch 34/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.4085 - accuracy: 0.4345
# Epoch 35/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.3583 - accuracy: 0.4425
# Epoch 36/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.3084 - accuracy: 0.4518
# Epoch 37/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.2612 - accuracy: 0.4615
# Epoch 38/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.2135 - accuracy: 0.4699
# Epoch 39/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.1683 - accuracy: 0.4790
# Epoch 40/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.1253 - accuracy: 0.4877
# Epoch 41/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.0819 - accuracy: 0.4980
# Epoch 42/150
# 394/394 [==============================] - 9s 23ms/step - loss: 2.0357 - accuracy: 0.5065
# Epoch 43/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.9962 - accuracy: 0.5146
# Epoch 44/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.9542 - accuracy: 0.5231
# Epoch 45/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.9146 - accuracy: 0.5316
# Epoch 46/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.8744 - accuracy: 0.5402
# Epoch 47/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.8335 - accuracy: 0.5480
# Epoch 48/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.7933 - accuracy: 0.5580
# Epoch 49/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.7584 - accuracy: 0.5653
# Epoch 50/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.7191 - accuracy: 0.5735
# Epoch 51/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.6855 - accuracy: 0.5820
# Epoch 52/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.6444 - accuracy: 0.5903
# Epoch 53/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.6131 - accuracy: 0.5971
# Epoch 54/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.5775 - accuracy: 0.6051
# Epoch 55/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.5423 - accuracy: 0.6137
# Epoch 56/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.5097 - accuracy: 0.6210
# Epoch 57/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.4769 - accuracy: 0.6282
# Epoch 58/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.4463 - accuracy: 0.6363
# Epoch 59/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.4101 - accuracy: 0.6439
# Epoch 60/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.3794 - accuracy: 0.6526
# Epoch 61/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.3474 - accuracy: 0.6588
# Epoch 62/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.3201 - accuracy: 0.6651
# Epoch 63/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.2932 - accuracy: 0.6720
# Epoch 64/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.2648 - accuracy: 0.6787
# Epoch 65/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.2309 - accuracy: 0.6875
# Epoch 66/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.2063 - accuracy: 0.6925
# Epoch 67/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.1784 - accuracy: 0.6994
# Epoch 68/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.1516 - accuracy: 0.7066
# Epoch 69/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.1306 - accuracy: 0.7099
# Epoch 70/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.0981 - accuracy: 0.7182
# Epoch 71/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.0709 - accuracy: 0.7249
# Epoch 72/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.0521 - accuracy: 0.7288
# Epoch 73/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.0257 - accuracy: 0.7360
# Epoch 74/150
# 394/394 [==============================] - 9s 23ms/step - loss: 1.0040 - accuracy: 0.7403
# Epoch 75/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.9846 - accuracy: 0.7447
# Epoch 76/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.9647 - accuracy: 0.7499
# Epoch 77/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.9381 - accuracy: 0.7569
# Epoch 78/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.9111 - accuracy: 0.7637
# Epoch 79/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.8921 - accuracy: 0.7686
# Epoch 80/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.8763 - accuracy: 0.7739
# Epoch 81/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.8547 - accuracy: 0.7776
# Epoch 82/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.8355 - accuracy: 0.7818
# Epoch 83/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.8152 - accuracy: 0.7871
# Epoch 84/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.7997 - accuracy: 0.7908
# Epoch 85/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.7797 - accuracy: 0.7964
# Epoch 86/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.7629 - accuracy: 0.8006
# Epoch 87/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.7432 - accuracy: 0.8046
# Epoch 88/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.7254 - accuracy: 0.8096
# Epoch 89/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.7124 - accuracy: 0.8124
# Epoch 90/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.6912 - accuracy: 0.8182
# Epoch 91/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.6790 - accuracy: 0.8214
# Epoch 92/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.6658 - accuracy: 0.8246
# Epoch 93/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.6498 - accuracy: 0.8285
# Epoch 94/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.6370 - accuracy: 0.8313
# Epoch 95/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.6175 - accuracy: 0.8361
# Epoch 96/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.6039 - accuracy: 0.8399
# Epoch 97/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.5917 - accuracy: 0.8428
# Epoch 98/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.5831 - accuracy: 0.8448
# Epoch 99/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.5691 - accuracy: 0.8484
# Epoch 100/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.5474 - accuracy: 0.8564
# Epoch 101/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.5446 - accuracy: 0.8540
# Epoch 102/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.5393 - accuracy: 0.8557
# Epoch 103/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.5215 - accuracy: 0.8614
# Epoch 104/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.5162 - accuracy: 0.8620
# Epoch 105/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4940 - accuracy: 0.8675
# Epoch 106/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4747 - accuracy: 0.8738
# Epoch 107/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4669 - accuracy: 0.8762
# Epoch 108/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4697 - accuracy: 0.8733
# Epoch 109/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4736 - accuracy: 0.8703
# Epoch 110/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4501 - accuracy: 0.8784
# Epoch 111/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4302 - accuracy: 0.8849
# Epoch 112/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4272 - accuracy: 0.8848
# Epoch 113/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4107 - accuracy: 0.8893
# Epoch 114/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4026 - accuracy: 0.8921
# Epoch 115/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4037 - accuracy: 0.8904
# Epoch 116/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.4080 - accuracy: 0.8883
# Epoch 117/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3824 - accuracy: 0.8965
# Epoch 118/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3693 - accuracy: 0.8999
# Epoch 119/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3648 - accuracy: 0.9003
# Epoch 120/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3619 - accuracy: 0.9014
# Epoch 121/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3648 - accuracy: 0.8992
# Epoch 122/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3521 - accuracy: 0.9031
# Epoch 123/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3411 - accuracy: 0.9069
# Epoch 124/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3321 - accuracy: 0.9093
# Epoch 125/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3290 - accuracy: 0.9103
# Epoch 126/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3220 - accuracy: 0.9123
# Epoch 127/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3154 - accuracy: 0.9136
# Epoch 128/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3191 - accuracy: 0.9111
# Epoch 129/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3063 - accuracy: 0.9153
# Epoch 130/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2970 - accuracy: 0.9185
# Epoch 131/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.3042 - accuracy: 0.9155
# Epoch 132/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2901 - accuracy: 0.9199
# Epoch 133/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2730 - accuracy: 0.9253
# Epoch 134/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2595 - accuracy: 0.9299
# Epoch 135/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2899 - accuracy: 0.9182
# Epoch 136/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2967 - accuracy: 0.9159
# Epoch 137/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2788 - accuracy: 0.9213
# Epoch 138/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2719 - accuracy: 0.9237
# Epoch 139/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2388 - accuracy: 0.9355
# Epoch 140/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2294 - accuracy: 0.9388
# Epoch 141/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2372 - accuracy: 0.9345
# Epoch 142/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2497 - accuracy: 0.9293
# Epoch 143/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2699 - accuracy: 0.9218
# Epoch 144/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2735 - accuracy: 0.9203
# Epoch 145/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2337 - accuracy: 0.9357
# Epoch 146/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2242 - accuracy: 0.9375
# Epoch 147/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2163 - accuracy: 0.9401
# Epoch 148/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2141 - accuracy: 0.9403
# Epoch 149/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2175 - accuracy: 0.9388
# Epoch 150/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.2301 - accuracy: 0.9345

# %% [markdown]
# ## **Prediction**

# %%
import numpy as np
# generate a sequence from a language model
def generate_seq(model, tokenizer, seq_length, seed_text, n_words):
    result = list()
    in_text = seed_text
    # generate a fixed number of words
    for _ in range(n_words):
        # encode the text as integer
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        # truncate sequences to a fixed length
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        # predict probabilities for each word
        predict_x=model.predict(encoded, verbose=0) 
        yhat=np.argmax(predict_x,axis=1)
        # map predicted word index to word
        out_word = ''
        for word, index in tokenizer.word_index.items():
            if index == yhat:
                out_word = word
                break
        # append to input
        in_text += ' ' + out_word
        result.append(out_word)
    return ' '.join(result)

# %%
from random import randint
from pickle import load
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences
# load cleaned text sequences
in_filename = '/content/republic_clean_seq.txt'
doc = loading_file(in_filename)
lines = doc.split('\n')
seq_length = len(lines[0].split()) - 1
# load the model
model = load_model('model.h5')
# load the tokenizer
tokenizer = load(open('tokenizer.pkl', 'rb'))

# select a seed text
seed_text = lines[randint(0,len(lines))]
print(seed_text + '\n')
# Out:
# act as to give the man within him in some way or other the most complete mastery over the entire human creature he should watch over the manyheaded monster like a good husbandman fostering and cultivating the gentle qualities and preventing the wild ones from growing he should be making the

# %%
# generate new text
generated = generate_seq(model, tokenizer, seq_length, seed_text, 50)
print(generated)
# Out:
# lionheart his ally and in common care of them all should be uniting the several parts with one another and with himself yes he said that is quite what the maintainer of justice say and so from every point of view whether of pleasure honour or advantage the approver of

# %% [markdown]
# ## **Build Model GRU**

# %%
# define the model
def define_model(vocab_size, seq_length):
    model = Sequential()
    model.add(Embedding(vocab_size, 50, input_length=seq_length))
    model.add(GRU(128, return_sequences=True))
    model.add(Bidirectional(GRU(64)))
    model.add(Dense(300, activation='relu'))
    model.add(Dense(vocab_size, activation='softmax'))
    # compile network
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # summarize defined model
    model.summary()
    plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %%
model2 = define_model(vocab_size, seq_length)
# fit model
model2.fit(X, y, batch_size=300, epochs=150)
# save the model to file
model2.save('model.h5')
# save the tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 50)            391900
#
#  gru (GRU)                   (None, 50, 128)           69120
#
#  bidirectional (Bidirectiona  (None, 128)              74496
#  l)
#
#  dense (Dense)               (None, 300)               38700
#
#  dense_1 (Dense)             (None, 7838)              2359238
#
# =================================================================
# Total params: 2,933,454
# Trainable params: 2,933,454
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 394/394 [==============================] - 15s 22ms/step - loss: 6.3811 - accuracy: 0.0581
# Epoch 2/150
# 394/394 [==============================] - 9s 22ms/step - loss: 5.8868 - accuracy: 0.0874
# Epoch 3/150
# 394/394 [==============================] - 8s 22ms/step - loss: 5.4913 - accuracy: 0.1275
# Epoch 4/150
# 394/394 [==============================] - 8s 22ms/step - loss: 5.2009 - accuracy: 0.1500
# Epoch 5/150
# 394/394 [==============================] - 8s 21ms/step - loss: 4.9644 - accuracy: 0.1648
# Epoch 6/150
# 394/394 [==============================] - 8s 21ms/step - loss: 4.7598 - accuracy: 0.1773
# Epoch 7/150
# 394/394 [==============================] - 8s 21ms/step - loss: 4.5737 - accuracy: 0.1870
# Epoch 8/150
# 394/394 [==============================] - 8s 21ms/step - loss: 4.3891 - accuracy: 0.1945
# Epoch 9/150
# 394/394 [==============================] - 8s 21ms/step - loss: 4.1971 - accuracy: 0.2026
# Epoch 10/150
# 394/394 [==============================] - 8s 21ms/step - loss: 3.9924 - accuracy: 0.2150
# Epoch 11/150
# 394/394 [==============================] - 8s 22ms/step - loss: 3.7745 - accuracy: 0.2338
# Epoch 12/150
# 394/394 [==============================] - 8s 21ms/step - loss: 3.5509 - accuracy: 0.2631
# Epoch 13/150
# 394/394 [==============================] - 8s 21ms/step - loss: 3.3374 - accuracy: 0.2936
# Epoch 14/150
# 394/394 [==============================] - 8s 21ms/step - loss: 3.1401 - accuracy: 0.3219
# Epoch 15/150
# 394/394 [==============================] - 8s 22ms/step - loss: 2.9634 - accuracy: 0.3489
# Epoch 16/150
# 394/394 [==============================] - 9s 22ms/step - loss: 2.8061 - accuracy: 0.3733
# Epoch 17/150
# 394/394 [==============================] - 9s 22ms/step - loss: 2.6613 - accuracy: 0.3960
# Epoch 18/150
# 394/394 [==============================] - 9s 22ms/step - loss: 2.5299 - accuracy: 0.4188
# Epoch 19/150
# 394/394 [==============================] - 9s 22ms/step - loss: 2.4114 - accuracy: 0.4403
# Epoch 20/150
# 394/394 [==============================] - 9s 22ms/step - loss: 2.2982 - accuracy: 0.4621
# Epoch 21/150
# 394/394 [==============================] - 9s 22ms/step - loss: 2.1963 - accuracy: 0.4817
# Epoch 22/150
# 394/394 [==============================] - 9s 22ms/step - loss: 2.1001 - accuracy: 0.4994
# Epoch 23/150
# 394/394 [==============================] - 9s 22ms/step - loss: 2.0072 - accuracy: 0.5180
# Epoch 24/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.9205 - accuracy: 0.5356
# Epoch 25/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.8395 - accuracy: 0.5510
# Epoch 26/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.7611 - accuracy: 0.5686
# Epoch 27/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.6852 - accuracy: 0.5862
# Epoch 28/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.6118 - accuracy: 0.6023
# Epoch 29/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.5448 - accuracy: 0.6164
# Epoch 30/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.4767 - accuracy: 0.6321
# Epoch 31/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.4124 - accuracy: 0.6464
# Epoch 32/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.3489 - accuracy: 0.6618
# Epoch 33/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.2898 - accuracy: 0.6746
# Epoch 34/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.2294 - accuracy: 0.6888
# Epoch 35/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.1748 - accuracy: 0.7016
# Epoch 36/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.1182 - accuracy: 0.7155
# Epoch 37/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.0671 - accuracy: 0.7277
# Epoch 38/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.0171 - accuracy: 0.7394
# Epoch 39/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.9670 - accuracy: 0.7530
# Epoch 40/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.9207 - accuracy: 0.7654
# Epoch 41/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.8732 - accuracy: 0.7759
# Epoch 42/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.8311 - accuracy: 0.7869
# Epoch 43/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.7858 - accuracy: 0.7987
# Epoch 44/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.7451 - accuracy: 0.8087
# Epoch 45/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.7073 - accuracy: 0.8187
# Epoch 46/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.6717 - accuracy: 0.8273
# Epoch 47/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.6342 - accuracy: 0.8367
# Epoch 48/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.6020 - accuracy: 0.8447
# Epoch 49/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.5679 - accuracy: 0.8538
# Epoch 50/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.5332 - accuracy: 0.8640
# Epoch 51/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.5104 - accuracy: 0.8690
# Epoch 52/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.4820 - accuracy: 0.8770
# Epoch 53/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.4582 - accuracy: 0.8827
# Epoch 54/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.4303 - accuracy: 0.8900
# Epoch 55/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.4077 - accuracy: 0.8952
# Epoch 56/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.3815 - accuracy: 0.9028
# Epoch 57/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.3582 - accuracy: 0.9090
# Epoch 58/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.3418 - accuracy: 0.9131
# Epoch 59/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.3288 - accuracy: 0.9148
# Epoch 60/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.3149 - accuracy: 0.9193
# Epoch 61/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.3014 - accuracy: 0.9220
# Epoch 62/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2840 - accuracy: 0.9267
# Epoch 63/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2619 - accuracy: 0.9329
# Epoch 64/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2430 - accuracy: 0.9388
# Epoch 65/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2338 - accuracy: 0.9400
# Epoch 66/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2306 - accuracy: 0.9405
# Epoch 67/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2274 - accuracy: 0.9400
# Epoch 68/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2119 - accuracy: 0.9452
# Epoch 69/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2054 - accuracy: 0.9466
# Epoch 70/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1982 - accuracy: 0.9478
# Epoch 71/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1892 - accuracy: 0.9503
# Epoch 72/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1777 - accuracy: 0.9533
# Epoch 73/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1744 - accuracy: 0.9539
# Epoch 74/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1672 - accuracy: 0.9563
# Epoch 75/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1685 - accuracy: 0.9543
# Epoch 76/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1647 - accuracy: 0.9561
# Epoch 77/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1481 - accuracy: 0.9611
# Epoch 78/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1441 - accuracy: 0.9623
# Epoch 79/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1464 - accuracy: 0.9607
# Epoch 80/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1620 - accuracy: 0.9545
# Epoch 81/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1583 - accuracy: 0.9545
# Epoch 82/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1410 - accuracy: 0.9604
# Epoch 83/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1196 - accuracy: 0.9685
# Epoch 84/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1069 - accuracy: 0.9732
# Epoch 85/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1235 - accuracy: 0.9663
# Epoch 86/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1699 - accuracy: 0.9490
# Epoch 87/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1813 - accuracy: 0.9441
# Epoch 88/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1292 - accuracy: 0.9635
# Epoch 89/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0822 - accuracy: 0.9806
# Epoch 90/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0534 - accuracy: 0.9904
# Epoch 91/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0336 - accuracy: 0.9960
# Epoch 92/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0204 - accuracy: 0.9989
# Epoch 93/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0126 - accuracy: 0.9998
# Epoch 94/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0080 - accuracy: 0.9999
# Epoch 95/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0091 - accuracy: 0.9998
# Epoch 96/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.8389 - accuracy: 0.7974
# Epoch 97/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.5402 - accuracy: 0.8386
# Epoch 98/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1377 - accuracy: 0.9592
# Epoch 99/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0441 - accuracy: 0.9935
# Epoch 100/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0188 - accuracy: 0.9997
# Epoch 101/150
# 394/394 [==============================] - 9s 23ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 102/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 103/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 104/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 105/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 106/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 107/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 108/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 109/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 110/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0035 - accuracy: 0.9999
# Epoch 111/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.5796 - accuracy: 0.6579
# Epoch 112/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.4164 - accuracy: 0.8711
# Epoch 113/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.1144 - accuracy: 0.9676
# Epoch 114/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0405 - accuracy: 0.9954
# Epoch 115/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0181 - accuracy: 0.9998
# Epoch 116/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 117/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 118/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 119/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 120/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 121/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 122/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 123/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 124/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 125/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 126/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 127/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.8287 - accuracy: 0.8409
# Epoch 128/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.0383 - accuracy: 0.7403
# Epoch 129/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2297 - accuracy: 0.9256
# Epoch 130/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0691 - accuracy: 0.9843
# Epoch 131/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0272 - accuracy: 0.9981
# Epoch 132/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0131 - accuracy: 0.9999
# Epoch 133/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 134/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 135/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 136/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 137/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 138/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 139/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 140/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 141/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 142/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 143/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 144/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 145/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.5335 - accuracy: 0.9014
# Epoch 146/150
# 394/394 [==============================] - 9s 22ms/step - loss: 1.2749 - accuracy: 0.7039
# Epoch 147/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.2718 - accuracy: 0.9137
# Epoch 148/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0794 - accuracy: 0.9797
# Epoch 149/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0279 - accuracy: 0.9974
# Epoch 150/150
# 394/394 [==============================] - 9s 22ms/step - loss: 0.0129 - accuracy: 0.9998

# %% [markdown]
# #Generated seq. for GRU model

# %%
generated = generate_seq(model2, tokenizer, seq_length, seed_text, 50)
print(generated)
# Out:
# lionheart his ally and in common care of them all should be uniting the several parts with one another and with himself yes he said that is quite what the maintainer of justice say and so from every point of view whether of pleasure honour or advantage the approver of

# %% [markdown]
# ## **Build Model RNN**

# %%
import tensorflow.keras.models as models
import tensorflow.keras.layers as layers
# define the model
def define_model(vocab_size, seq_length):
    model = Sequential()
    model.add(Embedding(vocab_size, 50, input_length=seq_length))
    model.add(layers.SimpleRNN(128, return_sequences=True))
    model.add(layers.SimpleRNN(64, return_sequences=True))
    model.add(layers.SimpleRNN(64))
    model.add(Dense(300, activation='relu'))
    model.add(Dense(vocab_size, activation='softmax'))
    # compile network
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # summarize defined model
    model.summary()
    plot_model(model, to_file='model1.png', show_shapes=True)
    return model

# %%
# define model
model1 = define_model(vocab_size, seq_length)
# fit model
model1.fit(X, y, batch_size=512, epochs=100)
# save the model to file
model1.save('model.h5')
# save the tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 50, 50)            391900
#
#  simple_rnn (SimpleRNN)      (None, 50, 128)           22912
#
#  simple_rnn_1 (SimpleRNN)    (None, 50, 64)            12352
#
#  simple_rnn_2 (SimpleRNN)    (None, 64)                8256
#
#  dense_2 (Dense)             (None, 300)               19500
#
#  dense_3 (Dense)             (None, 7838)              2359238
#
# =================================================================
# Total params: 2,814,158
# Trainable params: 2,814,158
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 231/231 [==============================] - 35s 146ms/step - loss: 6.3828 - accuracy: 0.0559
# Epoch 2/100
# 231/231 [==============================] - 34s 147ms/step - loss: 6.1306 - accuracy: 0.0631
# Epoch 3/100
# 231/231 [==============================] - 34s 148ms/step - loss: 5.8339 - accuracy: 0.0959
# Epoch 4/100
# 231/231 [==============================] - 34s 145ms/step - loss: 5.6346 - accuracy: 0.1043
# Epoch 5/100
# 231/231 [==============================] - 34s 146ms/step - loss: 5.4334 - accuracy: 0.1232
# Epoch 6/100
# 231/231 [==============================] - 35s 150ms/step - loss: 5.2496 - accuracy: 0.1391
# Epoch 7/100
# 231/231 [==============================] - 34s 148ms/step - loss: 5.1780 - accuracy: 0.1449
# Epoch 8/100
# 231/231 [==============================] - 34s 146ms/step - loss: 4.9993 - accuracy: 0.1572
# Epoch 9/100
# 231/231 [==============================] - 34s 148ms/step - loss: 4.8563 - accuracy: 0.1665
# Epoch 10/100
# 231/231 [==============================] - 35s 152ms/step - loss: 4.7249 - accuracy: 0.1754
# Epoch 11/100
# 231/231 [==============================] - 34s 148ms/step - loss: 4.5995 - accuracy: 0.1835
# Epoch 12/100
# 231/231 [==============================] - 34s 148ms/step - loss: 4.4626 - accuracy: 0.1913
# Epoch 13/100
# 231/231 [==============================] - 34s 148ms/step - loss: 4.3405 - accuracy: 0.1982
# Epoch 14/100
# 231/231 [==============================] - 34s 148ms/step - loss: 4.2482 - accuracy: 0.2055
# Epoch 15/100
# 231/231 [==============================] - 34s 149ms/step - loss: 4.1083 - accuracy: 0.2137
# Epoch 16/100
# 231/231 [==============================] - 35s 151ms/step - loss: 3.9756 - accuracy: 0.2245
# Epoch 17/100
# 231/231 [==============================] - 35s 149ms/step - loss: 3.8502 - accuracy: 0.2341
# Epoch 18/100
# 231/231 [==============================] - 34s 148ms/step - loss: 3.7223 - accuracy: 0.2475
# Epoch 19/100
# 231/231 [==============================] - 34s 148ms/step - loss: 3.6020 - accuracy: 0.2622
# Epoch 20/100
# 231/231 [==============================] - 34s 146ms/step - loss: 3.7110 - accuracy: 0.2528
# Epoch 21/100
# 231/231 [==============================] - 34s 145ms/step - loss: 3.5380 - accuracy: 0.2716
# Epoch 22/100
# 231/231 [==============================] - 34s 146ms/step - loss: 3.4056 - accuracy: 0.2889
# Epoch 23/100
# 231/231 [==============================] - 33s 145ms/step - loss: 3.2940 - accuracy: 0.3029
# Epoch 24/100
# 231/231 [==============================] - 33s 145ms/step - loss: 3.1962 - accuracy: 0.3172
# Epoch 25/100
# 231/231 [==============================] - 34s 145ms/step - loss: 3.0935 - accuracy: 0.3317
# Epoch 26/100
# 231/231 [==============================] - 33s 143ms/step - loss: 2.9950 - accuracy: 0.3479
# Epoch 27/100
# 231/231 [==============================] - 34s 145ms/step - loss: 2.9068 - accuracy: 0.3599
# Epoch 28/100
# 231/231 [==============================] - 34s 146ms/step - loss: 2.8280 - accuracy: 0.3734
# Epoch 29/100
# 231/231 [==============================] - 33s 145ms/step - loss: 2.7466 - accuracy: 0.3856
# Epoch 30/100
# 231/231 [==============================] - 34s 146ms/step - loss: 2.6633 - accuracy: 0.3998
# Epoch 31/100
# 231/231 [==============================] - 34s 147ms/step - loss: 2.5886 - accuracy: 0.4114
# Epoch 32/100
# 231/231 [==============================] - 34s 147ms/step - loss: 2.5158 - accuracy: 0.4258
# Epoch 33/100
# 231/231 [==============================] - 33s 145ms/step - loss: 2.4511 - accuracy: 0.4367
# Epoch 34/100
# 231/231 [==============================] - 33s 145ms/step - loss: 2.3849 - accuracy: 0.4489
# Epoch 35/100
# 231/231 [==============================] - 33s 144ms/step - loss: 2.3278 - accuracy: 0.4582
# Epoch 36/100
# 231/231 [==============================] - 33s 142ms/step - loss: 2.2712 - accuracy: 0.4694
# Epoch 37/100
# 231/231 [==============================] - 33s 144ms/step - loss: 2.2005 - accuracy: 0.4841
# Epoch 38/100
# 231/231 [==============================] - 33s 142ms/step - loss: 2.1536 - accuracy: 0.4910
# Epoch 39/100
# 231/231 [==============================] - 34s 146ms/step - loss: 2.1056 - accuracy: 0.5013
# Epoch 40/100
# 231/231 [==============================] - 34s 146ms/step - loss: 2.0579 - accuracy: 0.5103
# Epoch 41/100
# 231/231 [==============================] - 34s 147ms/step - loss: 1.9996 - accuracy: 0.5237
# Epoch 42/100
# 231/231 [==============================] - 33s 145ms/step - loss: 1.9515 - accuracy: 0.5333
# Epoch 43/100
# 231/231 [==============================] - 33s 142ms/step - loss: 1.9076 - accuracy: 0.5401
# Epoch 44/100
# 231/231 [==============================] - 33s 143ms/step - loss: 1.8708 - accuracy: 0.5470
# Epoch 45/100
# 231/231 [==============================] - 33s 142ms/step - loss: 1.8296 - accuracy: 0.5565
# Epoch 46/100
# 231/231 [==============================] - 33s 145ms/step - loss: 1.7871 - accuracy: 0.5658
# Epoch 47/100
# 231/231 [==============================] - 34s 145ms/step - loss: 1.7574 - accuracy: 0.5708
# Epoch 48/100
# 231/231 [==============================] - 33s 145ms/step - loss: 1.7132 - accuracy: 0.5811
# Epoch 49/100
# 231/231 [==============================] - 33s 144ms/step - loss: 1.6731 - accuracy: 0.5901
# Epoch 50/100
# 231/231 [==============================] - 33s 144ms/step - loss: 1.6329 - accuracy: 0.5997
# Epoch 51/100
# 231/231 [==============================] - 33s 143ms/step - loss: 1.6078 - accuracy: 0.6040
# Epoch 52/100
# 231/231 [==============================] - 33s 143ms/step - loss: 1.5763 - accuracy: 0.6099
# Epoch 53/100
# 231/231 [==============================] - 34s 145ms/step - loss: 1.5411 - accuracy: 0.6192
# Epoch 54/100
# 231/231 [==============================] - 33s 141ms/step - loss: 1.5121 - accuracy: 0.6242
# Epoch 55/100
# 231/231 [==============================] - 33s 143ms/step - loss: 1.4894 - accuracy: 0.6285
# Epoch 56/100
# 231/231 [==============================] - 33s 142ms/step - loss: 1.4652 - accuracy: 0.6348
# Epoch 57/100
# 231/231 [==============================] - 33s 142ms/step - loss: 1.4171 - accuracy: 0.6460
# Epoch 58/100
# 231/231 [==============================] - 33s 144ms/step - loss: 1.3968 - accuracy: 0.6502
# Epoch 59/100
# 231/231 [==============================] - 33s 142ms/step - loss: 1.3751 - accuracy: 0.6552
# Epoch 60/100
# 231/231 [==============================] - 33s 144ms/step - loss: 1.3575 - accuracy: 0.6581
# Epoch 61/100
# 231/231 [==============================] - 33s 144ms/step - loss: 1.3225 - accuracy: 0.6664
# Epoch 62/100
# 231/231 [==============================] - 34s 147ms/step - loss: 1.3033 - accuracy: 0.6706
# Epoch 63/100
# 231/231 [==============================] - 33s 144ms/step - loss: 1.2754 - accuracy: 0.6782
# Epoch 64/100
# 231/231 [==============================] - 33s 144ms/step - loss: 1.2451 - accuracy: 0.6862
# Epoch 65/100
# 231/231 [==============================] - 35s 150ms/step - loss: 1.2251 - accuracy: 0.6893
# Epoch 66/100
# 231/231 [==============================] - 38s 165ms/step - loss: 1.2202 - accuracy: 0.6898
# Epoch 67/100
# 231/231 [==============================] - 37s 160ms/step - loss: 1.2044 - accuracy: 0.6927
# Epoch 68/100
# 231/231 [==============================] - 37s 160ms/step - loss: 1.1613 - accuracy: 0.7052
# Epoch 69/100
# 231/231 [==============================] - 37s 160ms/step - loss: 1.1400 - accuracy: 0.7094
# Epoch 70/100
# 231/231 [==============================] - 35s 151ms/step - loss: 1.1296 - accuracy: 0.7117
# Epoch 71/100
# 231/231 [==============================] - 35s 150ms/step - loss: 1.1173 - accuracy: 0.7131
# Epoch 72/100
# 231/231 [==============================] - 36s 157ms/step - loss: 1.0966 - accuracy: 0.7176
# Epoch 73/100
# 231/231 [==============================] - 37s 161ms/step - loss: 1.0909 - accuracy: 0.7194
# Epoch 74/100
# 231/231 [==============================] - 37s 160ms/step - loss: 1.0631 - accuracy: 0.7271
# Epoch 75/100
# 231/231 [==============================] - 35s 150ms/step - loss: 1.0467 - accuracy: 0.7304
# Epoch 76/100
# 231/231 [==============================] - 34s 149ms/step - loss: 1.0354 - accuracy: 0.7314
# Epoch 77/100
# 231/231 [==============================] - 36s 154ms/step - loss: 1.0193 - accuracy: 0.7352
# Epoch 78/100
# 231/231 [==============================] - 35s 151ms/step - loss: 1.0129 - accuracy: 0.7364
# Epoch 79/100
# 231/231 [==============================] - 34s 147ms/step - loss: 0.9913 - accuracy: 0.7423
# Epoch 80/100
# 231/231 [==============================] - 34s 145ms/step - loss: 0.9664 - accuracy: 0.7489
# Epoch 81/100
# 231/231 [==============================] - 33s 145ms/step - loss: 0.9625 - accuracy: 0.7485
# Epoch 82/100
# 231/231 [==============================] - 34s 146ms/step - loss: 0.9496 - accuracy: 0.7517
# Epoch 83/100
# 231/231 [==============================] - 33s 145ms/step - loss: 0.9246 - accuracy: 0.7584
# Epoch 84/100
# 231/231 [==============================] - 34s 145ms/step - loss: 0.9168 - accuracy: 0.7609
# Epoch 85/100
# 231/231 [==============================] - 34s 145ms/step - loss: 0.8900 - accuracy: 0.7671
# Epoch 86/100
# 231/231 [==============================] - 33s 144ms/step - loss: 0.8875 - accuracy: 0.7677
# Epoch 87/100
# 231/231 [==============================] - 33s 143ms/step - loss: 0.8896 - accuracy: 0.7654
# Epoch 88/100
# 231/231 [==============================] - 34s 146ms/step - loss: 0.8788 - accuracy: 0.7674
# Epoch 89/100
# 231/231 [==============================] - 33s 145ms/step - loss: 0.8592 - accuracy: 0.7740
# Epoch 90/100
# 231/231 [==============================] - 34s 146ms/step - loss: 0.8447 - accuracy: 0.7766
# Epoch 91/100
# 231/231 [==============================] - 34s 146ms/step - loss: 0.8301 - accuracy: 0.7820
# Epoch 92/100
# 231/231 [==============================] - 34s 145ms/step - loss: 0.8288 - accuracy: 0.7796
# Epoch 93/100
# 231/231 [==============================] - 33s 144ms/step - loss: 0.8206 - accuracy: 0.7815
# Epoch 94/100
# 231/231 [==============================] - 33s 145ms/step - loss: 0.8015 - accuracy: 0.7869
# Epoch 95/100
# 231/231 [==============================] - 34s 145ms/step - loss: 0.7854 - accuracy: 0.7905
# Epoch 96/100
# 231/231 [==============================] - 33s 144ms/step - loss: 0.7746 - accuracy: 0.7939
# Epoch 97/100
# 231/231 [==============================] - 33s 144ms/step - loss: 0.7689 - accuracy: 0.7954
# Epoch 98/100
# 231/231 [==============================] - 34s 146ms/step - loss: 0.7572 - accuracy: 0.7986
# Epoch 99/100
# 231/231 [==============================] - 34s 149ms/step - loss: 0.7572 - accuracy: 0.7970
# Epoch 100/100
# 231/231 [==============================] - 34s 148ms/step - loss: 0.7428 - accuracy: 0.8014

# %% [markdown]
# #Generated seq. for rnn model

# %%
generated = generate_seq(model1, tokenizer, seq_length, seed_text, 50)
print(generated)
# Out:
# lionheart his ally and in common marriage and where the state whereas the number having an march upwards is to be the reflection and the unjust is wise or right than the style certainly he said i agree he said they are to be told and other cities should agree
